# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %%
sample_document=open('Pune.txt').read()

# %%
sample_document
# Out:
# 'Pune, often referred to as the "Oxford of the East," is a vibrant city located in the state of Maharashtra, India.\nWith a rich historical heritage dating back to the Maratha Empire, Pune has evolved into a bustling metropolis while retaining its cultural charm.\nKnown for its pleasant climate throughout the year, Pune attracts students, professionals, and tourists alike.\nThe city boasts a blend of modern infrastructure and historical landmarks, such as the Shaniwar Wada, Aga Khan Palace, and Sinhagad Fort.\nPune is also famous for its educational institutions, including renowned universities like Savitribai Phule Pune University and the Indian Institute of Science Education and Research (IISER).\nAs a hub for IT and manufacturing industries, Pune contributes significantly to India\'s economy and is home to numerous multinational corporations.\nThe city\'s diverse culinary scene offers a range of delicious street food, Maharashtrian delicacies, and international cuisines.\nPune\'s lively street markets and upscale malls cater to the shopping needs of residents and visitors.\nThe annual Ganesh Chaturthi festival is celebrated with great fervor in Pune, attracting devotees from all over the country.\nPune\'s nightlife scene is vibrant, with a plethora of bars, pubs, and lounges offering entertainment options for all tastes.\nThe city is surrounded by picturesque hills and scenic landscapes, making it a popular destination for nature lovers and adventure enthusiasts.\nPune\'s cultural fabric is enriched by its thriving music, art, and theater communities, hosting numerous events and festivals year-round.\nThe local transportation network, including buses and suburban trains, facilitates easy commuting within the city and to nearby towns.\nPune is also known for its thriving startup ecosystem, fostering innovation and entrepreneurship.\nThe traditional Maharashtrian hospitality is evident in Pune\'s welcoming atmosphere and friendly locals.\nThe city\'s diverse population reflects its cosmopolitan character, with people from various backgrounds living harmoniously.\nPune\'s educational institutions attract students not only from India but also from around the world, contributing to its multicultural environment.\nPune\'s strategic location, close to Mumbai, India\'s financial capital, enhances its significance as a major economic and cultural center.\nThe city\'s cultural heritage is preserved through various initiatives, including museums, heritage walks, and conservation efforts.\nOverall, Pune\'s dynamic blend of history, culture, education, and industry makes it a city with a unique charm and endless opportunities for exploration.'

# %%
#WORD TOken
tokens = word_tokenize(sample_document)
tokens
# Out:
# ['Pune',
#  ',',
#  'often',
#  'referred',
#  'to',
#  'as',
#  'the',
#  '``',
#  'Oxford',
#  'of',
#  'the',
#  'East',
#  ',',
#  "''",
#  'is',
#  'a',
#  'vibrant',
#  'city',
#  'located',
#  'in',
#  'the',
#  'state',
#  'of',
#  'Maharashtra',
#  ',',
#  'India',
#  '.',
#  'With',
#  'a',
#  'rich',
#  'historical',
#  'heritage',
#  'dating',
#  'back',
#  'to',
#  'the',
#  'Maratha',
#  'Empire',
#  ',',
#  'Pune',
#  'has',
#  'evolved',
#  'into',
#  'a',
#  'bustling',
#  'metropolis',
#  'while',
#  'retaining',
#  'its',
#  'cultural',
#  'charm',
#  '.',
#  'Known',
#  'for',
#  'its',
#  'pleasant',
#  'climate',
#  'throughout',
#  'the',
#  'year',
#  ',',
#  'Pune',
#  'attracts',
#  'students',
#  ',',
#  'professionals',
#  ',',
#  'and',
#  'tourists',
#  'alike',
#  '.',
#  'The',
#  'city',
#  'boasts',
#  'a',
#  'blend',
#  'of',
#  'modern',
#  'infrastructure',
#  'and',
#  'historical',
#  'landmarks',
#  ',',
#  'such',
#  'as',
#  'the',
#  'Shaniwar',
#  'Wada',
#  ',',
#  'Aga',
#  'Khan',
#  'Palace',
#  ',',
#  'and',
#  'Sinhagad',
#  'Fort',
#  '.',
#  'Pune',
#  'is',
#  'also',
#  'famous',
#  'for',
#  'its',
#  'educational',
#  'institutions',
#  ',',
#  'including',
#  'renowned',
#  'universities',
#  'like',
#  'Savitribai',
#  'Phule',
#  'Pune',
#  'University',
#  'and',
#  'the',
#  'Indian',
#  'Institute',
#  'of',
#  'Science',
#  'Education',
#  'and',
#  'Research',
#  '(',
#  'IISER',
#  ')',
#  '.',
#  'As',
#  'a',
#  'hub',
#  'for',
#  'IT',
#  'and',
#  'manufacturing',
#  'industries',
#  ',',
#  'Pune',
#  'contributes',
#  'significantly',
#  'to',
#  'India',
#  "'s",
#  'economy',
#  'and',
#  'is',
#  'home',
#  'to',
#  'numerous',
#  'multinational',
#  'corporations',
#  '.',
#  'The',
#  'city',
#  "'s",
#  'diverse',
#  'culinary',
#  'scene',
#  'offers',
#  'a',
#  'range',
#  'of',
#  'delicious',
#  'street',
#  'food',
#  ',',
#  'Maharashtrian',
#  'delicacies',
#  ',',
#  'and',
#  'international',
#  'cuisines',
#  '.',
#  'Pune',
#  "'s",
#  'lively',
#  'street',
#  'markets',
#  'and',
#  'upscale',
#  'malls',
#  'cater',
#  'to',
#  'the',
#  'shopping',
#  'needs',
#  'of',
#  'residents',
#  'and',
#  'visitors',
#  '.',
#  'The',
#  'annual',
#  'Ganesh',
#  'Chaturthi',
#  'festival',
#  'is',
#  'celebrated',
#  'with',
#  'great',
#  'fervor',
#  'in',
#  'Pune',
#  ',',
#  'attracting',
#  'devotees',
#  'from',
#  'all',
#  'over',
#  'the',
#  'country',
#  '.',
#  'Pune',
#  "'s",
#  'nightlife',
#  'scene',
#  'is',
#  'vibrant',
#  ',',
#  'with',
#  'a',
#  'plethora',
#  'of',
#  'bars',
#  ',',
#  'pubs',
#  ',',
#  'and',
#  'lounges',
#  'offering',
#  'entertainment',
#  'options',
#  'for',
#  'all',
#  'tastes',
#  '.',
#  'The',
#  'city',
#  'is',
#  'surrounded',
#  'by',
#  'picturesque',
#  'hills',
#  'and',
#  'scenic',
#  'landscapes',
#  ',',
#  'making',
#  'it',
#  'a',
#  'popular',
#  'destination',
#  'for',
#  'nature',
#  'lovers',
#  'and',
#  'adventure',
#  'enthusiasts',
#  '.',
#  'Pune',
#  "'s",
#  'cultural',
#  'fabric',
#  'is',
#  'enriched',
#  'by',
#  'its',
#  'thriving',
#  'music',
#  ',',
#  'art',
#  ',',
#  'and',
#  'theater',
#  'communities',
#  ',',
#  'hosting',
#  'numerous',
#  'events',
#  'and',
#  'festivals',
#  'year-round',
#  '.',
#  'The',
#  'local',
#  'transportation',
#  'network',
#  ',',
#  'including',
#  'buses',
#  'and',
#  'suburban',
#  'trains',
#  ',',
#  'facilitates',
#  'easy',
#  'commuting',
#  'within',
#  'the',
#  'city',
#  'and',
#  'to',
#  'nearby',
#  'towns',
#  '.',
#  'Pune',
#  'is',
#  'also',
#  'known',
#  'for',
#  'its',
#  'thriving',
#  'startup',
#  'ecosystem',
#  ',',
#  'fostering',
#  'innovation',
#  'and',
#  'entrepreneurship',
#  '.',
#  'The',
#  'traditional',
#  'Maharashtrian',
#  'hospitality',
#  'is',
#  'evident',
#  'in',
#  'Pune',
#  "'s",
#  'welcoming',
#  'atmosphere',
#  'and',
#  'friendly',
#  'locals',
#  '.',
#  'The',
#  'city',
#  "'s",
#  'diverse',
#  'population',
#  'reflects',
#  'its',
#  'cosmopolitan',
#  'character',
#  ',',
#  'with',
#  'people',
#  'from',
#  'various',
#  'backgrounds',
#  'living',
#  'harmoniously',
#  '.',
#  'Pune',
#  "'s",
#  'educational',
#  'institutions',
#  'attract',
#  'students',
#  'not',
#  'only',
#  'from',
#  'India',
#  'but',
#  'also',
#  'from',
#  'around',
#  'the',
#  'world',
#  ',',
#  'contributing',
#  'to',
#  'its',
#  'multicultural',
#  'environment',
#  '.',
#  'Pune',
#  "'s",
#  'strategic',
#  'location',
#  ',',
#  'close',
#  'to',
#  'Mumbai',
#  ',',
#  'India',
#  "'s",
#  'financial',
#  'capital',
#  ',',
#  'enhances',
#  'its',
#  'significance',
#  'as',
#  'a',
#  'major',
#  'economic',
#  'and',
#  'cultural',
#  'center',
#  '.',
#  'The',
#  'city',
#  "'s",
#  'cultural',
#  'heritage',
#  'is',
#  'preserved',
#  'through',
#  'various',
#  'initiatives',
#  ',',
#  'including',
#  'museums',
#  ',',
#  'heritage',
#  'walks',
#  ',',
#  'and',
#  'conservation',
#  'efforts',
#  '.',
#  'Overall',
#  ',',
#  'Pune',
#  "'s",
#  'dynamic',
#  'blend',
#  'of',
#  'history',
#  ',',
#  'culture',
#  ',',
#  'education',
#  ',',
#  'and',
#  'industry',
#  'makes',
#  'it',
#  'a',
#  'city',
#  'with',
#  'a',
#  'unique',
#  'charm',
#  'and',
#  'endless',
#  'opportunities',
#  'for',
#  'exploration',
#  '.']

# %%
#pos tags
pos_tags = pos_tag(tokens)
pos_tags
# Out:
# [('Pune', 'NNP'),
#  (',', ','),
#  ('often', 'RB'),
#  ('referred', 'VBN'),
#  ('to', 'TO'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('``', '``'),
#  ('Oxford', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('East', 'NNP'),
#  (',', ','),
#  ("''", "''"),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('vibrant', 'JJ'),
#  ('city', 'NN'),
#  ('located', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('state', 'NN'),
#  ('of', 'IN'),
#  ('Maharashtra', 'NNP'),
#  (',', ','),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('With', 'IN'),
#  ('a', 'DT'),
#  ('rich', 'JJ'),
#  ('historical', 'JJ'),
#  ('heritage', 'NN'),
#  ('dating', 'VBG'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Maratha', 'NNP'),
#  ('Empire', 'NNP'),
#  (',', ','),
#  ('Pune', 'NNP'),
#  ('has', 'VBZ'),
#  ('evolved', 'VBN'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('bustling', 'NN'),
#  ('metropolis', 'NN'),
#  ('while', 'IN'),
#  ('retaining', 'VBG'),
#  ('its', 'PRP$'),
#  ('cultural', 'JJ'),
#  ('charm', 'NN'),
#  ('.', '.'),
#  ('Known', 'VBN'),
#  ('for', 'IN'),
#  ('its', 'PRP$'),
#  ('pleasant', 'NN'),
#  ('climate', 'NN'),
#  ('throughout', 'IN'),
#  ('the', 'DT'),
#  ('year', 'NN'),
#  (',', ','),
#  ('Pune', 'NNP'),
#  ('attracts', 'VBZ'),
#  ('students', 'NNS'),
#  (',', ','),
#  ('professionals', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('tourists', 'NNS'),
#  ('alike', 'RB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('city', 'NN'),
#  ('boasts', 'VBZ'),
#  ('a', 'DT'),
#  ('blend', 'NN'),
#  ('of', 'IN'),
#  ('modern', 'JJ'),
#  ('infrastructure', 'NN'),
#  ('and', 'CC'),
#  ('historical', 'JJ'),
#  ('landmarks', 'NNS'),
#  (',', ','),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('Shaniwar', 'NNP'),
#  ('Wada', 'NNP'),
#  (',', ','),
#  ('Aga', 'NNP'),
#  ('Khan', 'NNP'),
#  ('Palace', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Sinhagad', 'NNP'),
#  ('Fort', 'NNP'),
#  ('.', '.'),
#  ('Pune', 'NNP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('famous', 'JJ'),
#  ('for', 'IN'),
#  ('its', 'PRP$'),
#  ('educational', 'JJ'),
#  ('institutions', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('renowned', 'JJ'),
#  ('universities', 'NNS'),
#  ('like', 'IN'),
#  ('Savitribai', 'NNP'),
#  ('Phule', 'NNP'),
#  ('Pune', 'NNP'),
#  ('University', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Indian', 'JJ'),
#  ('Institute', 'NNP'),
#  ('of', 'IN'),
#  ('Science', 'NNP'),
#  ('Education', 'NNP'),
#  ('and', 'CC'),
#  ('Research', 'NNP'),
#  ('(', '('),
#  ('IISER', 'NNP'),
#  (')', ')'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('a', 'DT'),
#  ('hub', 'NN'),
#  ('for', 'IN'),
#  ('IT', 'NNP'),
#  ('and', 'CC'),
#  ('manufacturing', 'VBG'),
#  ('industries', 'NNS'),
#  (',', ','),
#  ('Pune', 'NNP'),
#  ('contributes', 'VBZ'),
#  ('significantly', 'RB'),
#  ('to', 'TO'),
#  ('India', 'NNP'),
#  ("'s", 'POS'),
#  ('economy', 'NN'),
#  ('and', 'CC'),
#  ('is', 'VBZ'),
#  ('home', 'NN'),
#  ('to', 'TO'),
#  ('numerous', 'JJ'),
#  ('multinational', 'JJ'),
#  ('corporations', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('city', 'NN'),
#  ("'s", 'POS'),
#  ('diverse', 'JJ'),
#  ('culinary', 'JJ'),
#  ('scene', 'NN'),
#  ('offers', 'VBZ'),
#  ('a', 'DT'),
#  ('range', 'NN'),
#  ('of', 'IN'),
#  ('delicious', 'JJ'),
#  ('street', 'NN'),
#  ('food', 'NN'),
#  (',', ','),
#  ('Maharashtrian', 'JJ'),
#  ('delicacies', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('international', 'JJ'),
#  ('cuisines', 'NNS'),
#  ('.', '.'),
#  ('Pune', 'NNP'),
#  ("'s", 'POS'),
#  ('lively', 'JJ'),
#  ('street', 'NN'),
#  ('markets', 'NNS'),
#  ('and', 'CC'),
#  ('upscale', 'JJ'),
#  ('malls', 'NNS'),
#  ('cater', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('shopping', 'NN'),
#  ('needs', 'NNS'),
#  ('of', 'IN'),
#  ('residents', 'NNS'),
#  ('and', 'CC'),
#  ('visitors', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('annual', 'JJ'),
#  ('Ganesh', 'NNP'),
#  ('Chaturthi', 'NNP'),
#  ('festival', 'NN'),
#  ('is', 'VBZ'),
#  ('celebrated', 'VBN'),
#  ('with', 'IN'),
#  ('great', 'JJ'),
#  ('fervor', 'NN'),
#  ('in', 'IN'),
#  ('Pune', 'NNP'),
#  (',', ','),
#  ('attracting', 'VBG'),
#  ('devotees', 'NNS'),
#  ('from', 'IN'),
#  ('all', 'DT'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('.', '.'),
#  ('Pune', 'NNP'),
#  ("'s", 'POS'),
#  ('nightlife', 'JJ'),
#  ('scene', 'NN'),
#  ('is', 'VBZ'),
#  ('vibrant', 'JJ'),
#  (',', ','),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('plethora', 'NN'),
#  ('of', 'IN'),
#  ('bars', 'NNS'),
#  (',', ','),
#  ('pubs', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('lounges', 'VBZ'),
#  ('offering', 'VBG'),
#  ('entertainment', 'NN'),
#  ('options', 'NNS'),
#  ('for', 'IN'),
#  ('all', 'DT'),
#  ('tastes', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('city', 'NN'),
#  ('is', 'VBZ'),
#  ('surrounded', 'VBN'),
#  ('by', 'IN'),
#  ('picturesque', 'NN'),
#  ('hills', 'NNS'),
#  ('and', 'CC'),
#  ('scenic', 'JJ'),
#  ('landscapes', 'NNS'),
#  (',', ','),
#  ('making', 'VBG'),
#  ('it', 'PRP'),
#  ('a', 'DT'),
#  ('popular', 'JJ'),
#  ('destination', 'NN'),
#  ('for', 'IN'),
#  ('nature', 'NN'),
#  ('lovers', 'NNS'),
#  ('and', 'CC'),
#  ('adventure', 'NN'),
#  ('enthusiasts', 'NNS'),
#  ('.', '.'),
#  ('Pune', 'NNP'),
#  ("'s", 'POS'),
#  ('cultural', 'JJ'),
#  ('fabric', 'NN'),
#  ('is', 'VBZ'),
#  ('enriched', 'VBN'),
#  ('by', 'IN'),
#  ('its', 'PRP$'),
#  ('thriving', 'NN'),
#  ('music', 'NN'),
#  (',', ','),
#  ('art', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('theater', 'NN'),
#  ('communities', 'NNS'),
#  (',', ','),
#  ('hosting', 'VBG'),
#  ('numerous', 'JJ'),
#  ('events', 'NNS'),
#  ('and', 'CC'),
#  ('festivals', 'NNS'),
#  ('year-round', 'RB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('local', 'JJ'),
#  ('transportation', 'NN'),
#  ('network', 'NN'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('buses', 'NNS'),
#  ('and', 'CC'),
#  ('suburban', 'JJ'),
#  ('trains', 'NNS'),
#  (',', ','),
#  ('facilitates', 'NNS'),
#  ('easy', 'VBP'),
#  ('commuting', 'VBG'),
#  ('within', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('and', 'CC'),
#  ('to', 'TO'),
#  ('nearby', 'JJ'),
#  ('towns', 'NNS'),
#  ('.', '.'),
#  ('Pune', 'NNP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('known', 'VBN'),
#  ('for', 'IN'),
#  ('its', 'PRP$'),
#  ('thriving', 'NN'),
#  ('startup', 'NN'),
#  ('ecosystem', 'NN'),
#  (',', ','),
#  ('fostering', 'VBG'),
#  ('innovation', 'NN'),
#  ('and', 'CC'),
#  ('entrepreneurship', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('traditional', 'JJ'),
#  ('Maharashtrian', 'JJ'),
#  ('hospitality', 'NN'),
#  ('is', 'VBZ'),
#  ('evident', 'JJ'),
#  ('in', 'IN'),
#  ('Pune', 'NNP'),
#  ("'s", 'POS'),
#  ('welcoming', 'NN'),
#  ('atmosphere', 'RB'),
#  ('and', 'CC'),
#  ('friendly', 'JJ'),
#  ('locals', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('city', 'NN'),
#  ("'s", 'POS'),
#  ('diverse', 'JJ'),
#  ('population', 'NN'),
#  ('reflects', 'VBZ'),
#  ('its', 'PRP$'),
#  ('cosmopolitan', 'JJ'),
#  ('character', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('people', 'NNS'),
#  ('from', 'IN'),
#  ('various', 'JJ'),
#  ('backgrounds', 'NNS'),
#  ('living', 'VBG'),
#  ('harmoniously', 'RB'),
#  ('.', '.'),
#  ('Pune', 'NNP'),
#  ("'s", 'POS'),
#  ('educational', 'JJ'),
#  ('institutions', 'NNS'),
#  ('attract', 'VBP'),
#  ('students', 'NNS'),
#  ('not', 'RB'),
#  ('only', 'RB'),
#  ('from', 'IN'),
#  ('India', 'NNP'),
#  ('but', 'CC'),
#  ('also', 'RB'),
#  ('from', 'IN'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  (',', ','),
#  ('contributing', 'VBG'),
#  ('to', 'TO'),
#  ('its', 'PRP$'),
#  ('multicultural', 'JJ'),
#  ('environment', 'NN'),
#  ('.', '.'),
#  ('Pune', 'NNP'),
#  ("'s", 'POS'),
#  ('strategic', 'JJ'),
#  ('location', 'NN'),
#  (',', ','),
#  ('close', 'RB'),
#  ('to', 'TO'),
#  ('Mumbai', 'NNP'),
#  (',', ','),
#  ('India', 'NNP'),
#  ("'s", 'POS'),
#  ('financial', 'JJ'),
#  ('capital', 'NN'),
#  (',', ','),
#  ('enhances', 'VBZ'),
#  ('its', 'PRP$'),
#  ('significance', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('major', 'JJ'),
#  ('economic', 'JJ'),
#  ('and', 'CC'),
#  ('cultural', 'JJ'),
#  ('center', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('city', 'NN'),
#  ("'s", 'POS'),
#  ('cultural', 'JJ'),
#  ('heritage', 'NN'),
#  ('is', 'VBZ'),
#  ('preserved', 'VBN'),
#  ('through', 'IN'),
#  ('various', 'JJ'),
#  ('initiatives', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('museums', 'NNS'),
#  (',', ','),
#  ('heritage', 'NN'),
#  ('walks', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('conservation', 'NN'),
#  ('efforts', 'NNS'),
#  ('.', '.'),
#  ('Overall', 'JJ'),
#  (',', ','),
#  ('Pune', 'NNP'),
#  ("'s", 'POS'),
#  ('dynamic', 'JJ'),
#  ('blend', 'NN'),
#  ('of', 'IN'),
#  ('history', 'NN'),
#  (',', ','),
#  ('culture', 'NN'),
#  (',', ','),
#  ('education', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('industry', 'NN'),
#  ('makes', 'VBZ'),
#  ('it', 'PRP'),
#  ('a', 'DT'),
#  ('city', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('unique', 'JJ'),
#  ('charm', 'NN'),
#  ('and', 'CC'),
#  ('endless', 'JJ'),
#  ('opportunities', 'NNS'),
#  ('for', 'IN'),
#  ('exploration', 'NN'),
#  ('.', '.')]

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

# %%
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

# %%
preprocessed_text = ' '.join(lemmatized_tokens)
preprocessed_text
# Out:
# "Pune , often referred `` Oxford East , '' vibrant city located state Maharashtra , India . rich historical heritage dating back Maratha Empire , Pune evolved bustling metropolis retaining cultural charm . Known pleasant climate throughout year , Pune attracts student , professional , tourist alike . city boast blend modern infrastructure historical landmark , Shaniwar Wada , Aga Khan Palace , Sinhagad Fort . Pune also famous educational institution , including renowned university like Savitribai Phule Pune University Indian Institute Science Education Research ( IISER ) . hub manufacturing industry , Pune contributes significantly India 's economy home numerous multinational corporation . city 's diverse culinary scene offer range delicious street food , Maharashtrian delicacy , international cuisine . Pune 's lively street market upscale mall cater shopping need resident visitor . annual Ganesh Chaturthi festival celebrated great fervor Pune , attracting devotee country . Pune 's nightlife scene vibrant , plethora bar , pub , lounge offering entertainment option taste . city surrounded picturesque hill scenic landscape , making popular destination nature lover adventure enthusiast . Pune 's cultural fabric enriched thriving music , art , theater community , hosting numerous event festival year-round . local transportation network , including bus suburban train , facilitates easy commuting within city nearby town . Pune also known thriving startup ecosystem , fostering innovation entrepreneurship . traditional Maharashtrian hospitality evident Pune 's welcoming atmosphere friendly local . city 's diverse population reflects cosmopolitan character , people various background living harmoniously . Pune 's educational institution attract student India also around world , contributing multicultural environment . Pune 's strategic location , close Mumbai , India 's financial capital , enhances significance major economic cultural center . city 's cultural heritage preserved various initiative , including museum , heritage walk , conservation effort . Overall , Pune 's dynamic blend history , culture , education , industry make city unique charm endless opportunity exploration ."

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform([preprocessed_text])
feature_names = tfidf_vectorizer.get_feature_names_out()
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# %%
print("Tokenization:", toke ns)
print("POS Tagging:", pos_tags)
print("Stop words removal:", filtered_tokens)
print("Stemming:", stemmed_tokens)
print("Lemmatization:", lemmatized_tokens)
print("\nPreprocessed Text:", preprocessed_text)
print("\nTF-IDF Representation:")
print(tfidf_df)
# Out:
# Tokenization: ['Pune', ',', 'often', 'referred', 'to', 'as', 'the', '``', 'Oxford', 'of', 'the', 'East', ',', "''", 'is', 'a', 'vibrant', 'city', 'located', 'in', 'the', 'state', 'of', 'Maharashtra', ',', 'India', '.', 'With', 'a', 'rich', 'historical', 'heritage', 'dating', 'back', 'to', 'the', 'Maratha', 'Empire', ',', 'Pune', 'has', 'evolved', 'into', 'a', 'bustling', 'metropolis', 'while', 'retaining', 'its', 'cultural', 'charm', '.', 'Known', 'for', 'its', 'pleasant', 'climate', 'throughout', 'the', 'year', ',', 'Pune', 'attracts', 'students', ',', 'professionals', ',', 'and', 'tourists', 'alike', '.', 'The', 'city', 'boasts', 'a', 'blend', 'of', 'modern', 'infrastructure', 'and', 'historical', 'landmarks', ',', 'such', 'as', 'the', 'Shaniwar', 'Wada', ',', 'Aga', 'Khan', 'Palace', ',', 'and', 'Sinhagad', 'Fort', '.', 'Pune', 'is', 'also', 'famous', 'for', 'its', 'educational', 'institutions', ',', 'including', 'renowned', 'universities', 'like', 'Savitribai', 'Phule', 'Pune', 'University', 'and', 'the', 'Indian', 'Institute', 'of', 'Science', 'Education', 'and', 'Research', '(', 'IISER', ')', '.', 'As', 'a', 'hub', 'for', 'IT', 'and', 'manufacturing', 'industries', ',', 'Pune', 'contributes', 'significantly', 'to', 'India', "'s", 'economy', 'and', 'is', 'home', 'to', 'numerous', 'multinational', 'corporations', '.', 'The', 'city', "'s", 'diverse', 'culinary', 'scene', 'offers', 'a', 'range', 'of', 'delicious', 'street', 'food', ',', 'Maharashtrian', 'delicacies', ',', 'and', 'international', 'cuisines', '.', 'Pune', "'s", 'lively', 'street', 'markets', 'and', 'upscale', 'malls', 'cater', 'to', 'the', 'shopping', 'needs', 'of', 'residents', 'and', 'visitors', '.', 'The', 'annual', 'Ganesh', 'Chaturthi', 'festival', 'is', 'celebrated', 'with', 'great', 'fervor', 'in', 'Pune', ',', 'attracting', 'devotees', 'from', 'all', 'over', 'the', 'country', '.', 'Pune', "'s", 'nightlife', 'scene', 'is', 'vibrant', ',', 'with', 'a', 'plethora', 'of', 'bars', ',', 'pubs', ',', 'and', 'lounges', 'offering', 'entertainment', 'options', 'for', 'all', 'tastes', '.', 'The', 'city', 'is', 'surrounded', 'by', 'picturesque', 'hills', 'and', 'scenic', 'landscapes', ',', 'making', 'it', 'a', 'popular', 'destination', 'for', 'nature', 'lovers', 'and', 'adventure', 'enthusiasts', '.', 'Pune', "'s", 'cultural', 'fabric', 'is', 'enriched', 'by', 'its', 'thriving', 'music', ',', 'art', ',', 'and', 'theater', 'communities', ',', 'hosting', 'numerous', 'events', 'and', 'festivals', 'year-round', '.', 'The', 'local', 'transportation', 'network', ',', 'including', 'buses', 'and', 'suburban', 'trains', ',', 'facilitates', 'easy', 'commuting', 'within', 'the', 'city', 'and', 'to', 'nearby', 'towns', '.', 'Pune', 'is', 'also', 'known', 'for', 'its', 'thriving', 'startup', 'ecosystem', ',', 'fostering', 'innovation', 'and', 'entrepreneurship', '.', 'The', 'traditional', 'Maharashtrian', 'hospitality', 'is', 'evident', 'in', 'Pune', "'s", 'welcoming', 'atmosphere', 'and', 'friendly', 'locals', '.', 'The', 'city', "'s", 'diverse', 'population', 'reflects', 'its', 'cosmopolitan', 'character', ',', 'with', 'people', 'from', 'various', 'backgrounds', 'living', 'harmoniously', '.', 'Pune', "'s", 'educational', 'institutions', 'attract', 'students', 'not', 'only', 'from', 'India', 'but', 'also', 'from', 'around', 'the', 'world', ',', 'contributing', 'to', 'its', 'multicultural', 'environment', '.', 'Pune', "'s", 'strategic', 'location', ',', 'close', 'to', 'Mumbai', ',', 'India', "'s", 'financial', 'capital', ',', 'enhances', 'its', 'significance', 'as', 'a', 'major', 'economic', 'and', 'cultural', 'center', '.', 'The', 'city', "'s", 'cultural', 'heritage', 'is', 'preserved', 'through', 'various', 'initiatives', ',', 'including', 'museums', ',', 'heritage', 'walks', ',', 'and', 'conservation', 'efforts', '.', 'Overall', ',', 'Pune', "'s", 'dynamic', 'blend', 'of', 'history', ',', 'culture', ',', 'education', ',', 'and', 'industry', 'makes', 'it', 'a', 'city', 'with ...
# POS Tagging: [('Pune', 'NNP'), (',', ','), ('often', 'RB'), ('referred', 'VBN'), ('to', 'TO'), ('as', 'IN'), ('the', 'DT'), ('``', '``'), ('Oxford', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('East', 'NNP'), (',', ','), ("''", "''"), ('is', 'VBZ'), ('a', 'DT'), ('vibrant', 'JJ'), ('city', 'NN'), ('located', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('state', 'NN'), ('of', 'IN'), ('Maharashtra', 'NNP'), (',', ','), ('India', 'NNP'), ('.', '.'), ('With', 'IN'), ('a', 'DT'), ('rich', 'JJ'), ('historical', 'JJ'), ('heritage', 'NN'), ('dating', 'VBG'), ('back', 'RB'), ('to', 'TO'), ('the', 'DT'), ('Maratha', 'NNP'), ('Empire', 'NNP'), (',', ','), ('Pune', 'NNP'), ('has', 'VBZ'), ('evolved', 'VBN'), ('into', 'IN'), ('a', 'DT'), ('bustling', 'NN'), ('metropolis', 'NN'), ('while', 'IN'), ('retaining', 'VBG'), ('its', 'PRP$'), ('cultural', 'JJ'), ('charm', 'NN'), ('.', '.'), ('Known', 'VBN'), ('for', 'IN'), ('its', 'PRP$'), ('pleasant', 'NN'), ('climate', 'NN'), ('throughout', 'IN'), ('the', 'DT'), ('year', 'NN'), (',', ','), ('Pune', 'NNP'), ('attracts', 'VBZ'), ('students', 'NNS'), (',', ','), ('professionals', 'NNS'), (',', ','), ('and', 'CC'), ('tourists', 'NNS'), ('alike', 'RB'), ('.', '.'), ('The', 'DT'), ('city', 'NN'), ('boasts', 'VBZ'), ('a', 'DT'), ('blend', 'NN'), ('of', 'IN'), ('modern', 'JJ'), ('infrastructure', 'NN'), ('and', 'CC'), ('historical', 'JJ'), ('landmarks', 'NNS'), (',', ','), ('such', 'JJ'), ('as', 'IN'), ('the', 'DT'), ('Shaniwar', 'NNP'), ('Wada', 'NNP'), (',', ','), ('Aga', 'NNP'), ('Khan', 'NNP'), ('Palace', 'NNP'), (',', ','), ('and', 'CC'), ('Sinhagad', 'NNP'), ('Fort', 'NNP'), ('.', '.'), ('Pune', 'NNP'), ('is', 'VBZ'), ('also', 'RB'), ('famous', 'JJ'), ('for', 'IN'), ('its', 'PRP$'), ('educational', 'JJ'), ('institutions', 'NNS'), (',', ','), ('including', 'VBG'), ('renowned', 'JJ'), ('universities', 'NNS'), ('like', 'IN'), ('Savitribai', 'NNP'), ('Phule', 'NNP'), ('Pune', 'NNP'), ('University', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('Indian', 'JJ'), ('Institute', 'NNP'), ('of', 'IN'), ('Science', 'NNP'), ('Education', 'NNP'), ('and', 'CC'), ('Research', 'NNP'), ('(', '('), ('IISER', 'NNP'), (')', ')'), ('.', '.'), ('As', 'IN'), ('a', 'DT'), ('hub', 'NN'), ('for', 'IN'), ('IT', 'NNP'), ('and', 'CC'), ('manufacturing', 'VBG'), ('industries', 'NNS'), (',', ','), ('Pune', 'NNP'), ('contributes', 'VBZ'), ('significantly', 'RB'), ('to', 'TO'), ('India', 'NNP'), ("'s", 'POS'), ('economy', 'NN'), ('and', 'CC'), ('is', 'VBZ'), ('home', 'NN'), ('to', 'TO'), ('numerous', 'JJ'), ('multinational', 'JJ'), ('corporations', 'NNS'), ('.', '.'), ('The', 'DT'), ('city', 'NN'), ("'s", 'POS'), ('diverse', 'JJ'), ('culinary', 'JJ'), ('scene', 'NN'), ('offers', 'VBZ'), ('a', 'DT'), ('range', 'NN'), ('of', 'IN'), ('delicious', 'JJ'), ('street', 'NN'), ('food', 'NN'), (',', ','), ('Maharashtrian', 'JJ'), ('delicacies', 'NNS'), (',', ','), ('and', 'CC'), ('international', 'JJ'), ('cuisines', 'NNS'), ('.', '.'), ('Pune', 'NNP'), ("'s", 'POS'), ('lively', 'JJ'), ('street', 'NN'), ('markets', 'NNS'), ('and', 'CC'), ('upscale', 'JJ'), ('malls', 'NNS'), ('cater', 'NN'), ('to', 'TO'), ('the', 'DT'), ('shopping', 'NN'), ('needs', 'NNS'), ('of', 'IN'), ('residents', 'NNS'), ('and', 'CC'), ('visitors', 'NNS'), ('.', '.'), ('The', 'DT'), ('annual', 'JJ'), ('Ganesh', 'NNP'), ('Chaturthi', 'NNP'), ('festival', 'NN'), ('is', 'VBZ'), ('celebrated', 'VBN'), ('with', 'IN'), ('great', 'JJ'), ('fervor', 'NN'), ('in', 'IN'), ('Pune', 'NNP'), (',', ','), ('attracting', 'VBG'), ('devotees', 'NNS'), ('from', 'IN'), ('all', 'DT'), ('over', 'IN'), ('the', 'DT'), ('country', 'NN'), ('.', '.'), ('Pune', 'NNP'), ("'s", 'POS'), ('nightlife', 'JJ'), ('scene', 'NN'), ('is', 'VBZ'), ('vibrant', 'JJ'), (',', ','), ('with', 'IN'), ('a', 'DT'), ('plethora', 'NN'), ('of', 'IN'), ('bars', 'NNS'), (',', ','), ('pubs', 'NNS'), (',', ','), ('and', 'CC'), ('lounges', 'VBZ'), ('offering', 'VBG'), ('entertainment', 'NN'), ('options', 'NNS'), ('for', 'IN'), ('all', 'DT'), ('tast ...
# Stop words removal: ['Pune', ',', 'often', 'referred', '``', 'Oxford', 'East', ',', "''", 'vibrant', 'city', 'located', 'state', 'Maharashtra', ',', 'India', '.', 'rich', 'historical', 'heritage', 'dating', 'back', 'Maratha', 'Empire', ',', 'Pune', 'evolved', 'bustling', 'metropolis', 'retaining', 'cultural', 'charm', '.', 'Known', 'pleasant', 'climate', 'throughout', 'year', ',', 'Pune', 'attracts', 'students', ',', 'professionals', ',', 'tourists', 'alike', '.', 'city', 'boasts', 'blend', 'modern', 'infrastructure', 'historical', 'landmarks', ',', 'Shaniwar', 'Wada', ',', 'Aga', 'Khan', 'Palace', ',', 'Sinhagad', 'Fort', '.', 'Pune', 'also', 'famous', 'educational', 'institutions', ',', 'including', 'renowned', 'universities', 'like', 'Savitribai', 'Phule', 'Pune', 'University', 'Indian', 'Institute', 'Science', 'Education', 'Research', '(', 'IISER', ')', '.', 'hub', 'manufacturing', 'industries', ',', 'Pune', 'contributes', 'significantly', 'India', "'s", 'economy', 'home', 'numerous', 'multinational', 'corporations', '.', 'city', "'s", 'diverse', 'culinary', 'scene', 'offers', 'range', 'delicious', 'street', 'food', ',', 'Maharashtrian', 'delicacies', ',', 'international', 'cuisines', '.', 'Pune', "'s", 'lively', 'street', 'markets', 'upscale', 'malls', 'cater', 'shopping', 'needs', 'residents', 'visitors', '.', 'annual', 'Ganesh', 'Chaturthi', 'festival', 'celebrated', 'great', 'fervor', 'Pune', ',', 'attracting', 'devotees', 'country', '.', 'Pune', "'s", 'nightlife', 'scene', 'vibrant', ',', 'plethora', 'bars', ',', 'pubs', ',', 'lounges', 'offering', 'entertainment', 'options', 'tastes', '.', 'city', 'surrounded', 'picturesque', 'hills', 'scenic', 'landscapes', ',', 'making', 'popular', 'destination', 'nature', 'lovers', 'adventure', 'enthusiasts', '.', 'Pune', "'s", 'cultural', 'fabric', 'enriched', 'thriving', 'music', ',', 'art', ',', 'theater', 'communities', ',', 'hosting', 'numerous', 'events', 'festivals', 'year-round', '.', 'local', 'transportation', 'network', ',', 'including', 'buses', 'suburban', 'trains', ',', 'facilitates', 'easy', 'commuting', 'within', 'city', 'nearby', 'towns', '.', 'Pune', 'also', 'known', 'thriving', 'startup', 'ecosystem', ',', 'fostering', 'innovation', 'entrepreneurship', '.', 'traditional', 'Maharashtrian', 'hospitality', 'evident', 'Pune', "'s", 'welcoming', 'atmosphere', 'friendly', 'locals', '.', 'city', "'s", 'diverse', 'population', 'reflects', 'cosmopolitan', 'character', ',', 'people', 'various', 'backgrounds', 'living', 'harmoniously', '.', 'Pune', "'s", 'educational', 'institutions', 'attract', 'students', 'India', 'also', 'around', 'world', ',', 'contributing', 'multicultural', 'environment', '.', 'Pune', "'s", 'strategic', 'location', ',', 'close', 'Mumbai', ',', 'India', "'s", 'financial', 'capital', ',', 'enhances', 'significance', 'major', 'economic', 'cultural', 'center', '.', 'city', "'s", 'cultural', 'heritage', 'preserved', 'various', 'initiatives', ',', 'including', 'museums', ',', 'heritage', 'walks', ',', 'conservation', 'efforts', '.', 'Overall', ',', 'Pune', "'s", 'dynamic', 'blend', 'history', ',', 'culture', ',', 'education', ',', 'industry', 'makes', 'city', 'unique', 'charm', 'endless', 'opportunities', 'exploration', '.']
# Stemming: ['pune', ',', 'often', 'refer', '``', 'oxford', 'east', ',', "''", 'vibrant', 'citi', 'locat', 'state', 'maharashtra', ',', 'india', '.', 'rich', 'histor', 'heritag', 'date', 'back', 'maratha', 'empir', ',', 'pune', 'evolv', 'bustl', 'metropoli', 'retain', 'cultur', 'charm', '.', 'known', 'pleasant', 'climat', 'throughout', 'year', ',', 'pune', 'attract', 'student', ',', 'profession', ',', 'tourist', 'alik', '.', 'citi', 'boast', 'blend', 'modern', 'infrastructur', 'histor', 'landmark', ',', 'shaniwar', 'wada', ',', 'aga', 'khan', 'palac', ',', 'sinhagad', 'fort', '.', 'pune', 'also', 'famou', 'educ', 'institut', ',', 'includ', 'renown', 'univers', 'like', 'savitribai', 'phule', 'pune', 'univers', 'indian', 'institut', 'scienc', 'educ', 'research', '(', 'iiser', ')', '.', 'hub', 'manufactur', 'industri', ',', 'pune', 'contribut', 'significantli', 'india', "'s", 'economi', 'home', 'numer', 'multin', 'corpor', '.', 'citi', "'s", 'divers', 'culinari', 'scene', 'offer', 'rang', 'delici', 'street', 'food', ',', 'maharashtrian', 'delicaci', ',', 'intern', 'cuisin', '.', 'pune', "'s", 'live', 'street', 'market', 'upscal', 'mall', 'cater', 'shop', 'need', 'resid', 'visitor', '.', 'annual', 'ganesh', 'chaturthi', 'festiv', 'celebr', 'great', 'fervor', 'pune', ',', 'attract', 'devote', 'countri', '.', 'pune', "'s", 'nightlif', 'scene', 'vibrant', ',', 'plethora', 'bar', ',', 'pub', ',', 'loung', 'offer', 'entertain', 'option', 'tast', '.', 'citi', 'surround', 'picturesqu', 'hill', 'scenic', 'landscap', ',', 'make', 'popular', 'destin', 'natur', 'lover', 'adventur', 'enthusiast', '.', 'pune', "'s", 'cultur', 'fabric', 'enrich', 'thrive', 'music', ',', 'art', ',', 'theater', 'commun', ',', 'host', 'numer', 'event', 'festiv', 'year-round', '.', 'local', 'transport', 'network', ',', 'includ', 'buse', 'suburban', 'train', ',', 'facilit', 'easi', 'commut', 'within', 'citi', 'nearbi', 'town', '.', 'pune', 'also', 'known', 'thrive', 'startup', 'ecosystem', ',', 'foster', 'innov', 'entrepreneurship', '.', 'tradit', 'maharashtrian', 'hospit', 'evid', 'pune', "'s", 'welcom', 'atmospher', 'friendli', 'local', '.', 'citi', "'s", 'divers', 'popul', 'reflect', 'cosmopolitan', 'charact', ',', 'peopl', 'variou', 'background', 'live', 'harmoni', '.', 'pune', "'s", 'educ', 'institut', 'attract', 'student', 'india', 'also', 'around', 'world', ',', 'contribut', 'multicultur', 'environ', '.', 'pune', "'s", 'strateg', 'locat', ',', 'close', 'mumbai', ',', 'india', "'s", 'financi', 'capit', ',', 'enhanc', 'signific', 'major', 'econom', 'cultur', 'center', '.', 'citi', "'s", 'cultur', 'heritag', 'preserv', 'variou', 'initi', ',', 'includ', 'museum', ',', 'heritag', 'walk', ',', 'conserv', 'effort', '.', 'overal', ',', 'pune', "'s", 'dynam', 'blend', 'histori', ',', 'cultur', ',', 'educ', ',', 'industri', 'make', 'citi', 'uniqu', 'charm', 'endless', 'opportun', 'explor', '.']
# Lemmatization: ['Pune', ',', 'often', 'referred', '``', 'Oxford', 'East', ',', "''", 'vibrant', 'city', 'located', 'state', 'Maharashtra', ',', 'India', '.', 'rich', 'historical', 'heritage', 'dating', 'back', 'Maratha', 'Empire', ',', 'Pune', 'evolved', 'bustling', 'metropolis', 'retaining', 'cultural', 'charm', '.', 'Known', 'pleasant', 'climate', 'throughout', 'year', ',', 'Pune', 'attracts', 'student', ',', 'professional', ',', 'tourist', 'alike', '.', 'city', 'boast', 'blend', 'modern', 'infrastructure', 'historical', 'landmark', ',', 'Shaniwar', 'Wada', ',', 'Aga', 'Khan', 'Palace', ',', 'Sinhagad', 'Fort', '.', 'Pune', 'also', 'famous', 'educational', 'institution', ',', 'including', 'renowned', 'university', 'like', 'Savitribai', 'Phule', 'Pune', 'University', 'Indian', 'Institute', 'Science', 'Education', 'Research', '(', 'IISER', ')', '.', 'hub', 'manufacturing', 'industry', ',', 'Pune', 'contributes', 'significantly', 'India', "'s", 'economy', 'home', 'numerous', 'multinational', 'corporation', '.', 'city', "'s", 'diverse', 'culinary', 'scene', 'offer', 'range', 'delicious', 'street', 'food', ',', 'Maharashtrian', 'delicacy', ',', 'international', 'cuisine', '.', 'Pune', "'s", 'lively', 'street', 'market', 'upscale', 'mall', 'cater', 'shopping', 'need', 'resident', 'visitor', '.', 'annual', 'Ganesh', 'Chaturthi', 'festival', 'celebrated', 'great', 'fervor', 'Pune', ',', 'attracting', 'devotee', 'country', '.', 'Pune', "'s", 'nightlife', 'scene', 'vibrant', ',', 'plethora', 'bar', ',', 'pub', ',', 'lounge', 'offering', 'entertainment', 'option', 'taste', '.', 'city', 'surrounded', 'picturesque', 'hill', 'scenic', 'landscape', ',', 'making', 'popular', 'destination', 'nature', 'lover', 'adventure', 'enthusiast', '.', 'Pune', "'s", 'cultural', 'fabric', 'enriched', 'thriving', 'music', ',', 'art', ',', 'theater', 'community', ',', 'hosting', 'numerous', 'event', 'festival', 'year-round', '.', 'local', 'transportation', 'network', ',', 'including', 'bus', 'suburban', 'train', ',', 'facilitates', 'easy', 'commuting', 'within', 'city', 'nearby', 'town', '.', 'Pune', 'also', 'known', 'thriving', 'startup', 'ecosystem', ',', 'fostering', 'innovation', 'entrepreneurship', '.', 'traditional', 'Maharashtrian', 'hospitality', 'evident', 'Pune', "'s", 'welcoming', 'atmosphere', 'friendly', 'local', '.', 'city', "'s", 'diverse', 'population', 'reflects', 'cosmopolitan', 'character', ',', 'people', 'various', 'background', 'living', 'harmoniously', '.', 'Pune', "'s", 'educational', 'institution', 'attract', 'student', 'India', 'also', 'around', 'world', ',', 'contributing', 'multicultural', 'environment', '.', 'Pune', "'s", 'strategic', 'location', ',', 'close', 'Mumbai', ',', 'India', "'s", 'financial', 'capital', ',', 'enhances', 'significance', 'major', 'economic', 'cultural', 'center', '.', 'city', "'s", 'cultural', 'heritage', 'preserved', 'various', 'initiative', ',', 'including', 'museum', ',', 'heritage', 'walk', ',', 'conservation', 'effort', '.', 'Overall', ',', 'Pune', "'s", 'dynamic', 'blend', 'history', ',', 'culture', ',', 'education', ',', 'industry', 'make', 'city', 'unique', 'charm', 'endless', 'opportunity', 'exploration', '.']
#
# Preprocessed Text: Pune , often referred `` Oxford East , '' vibrant city located state Maharashtra , India . rich historical heritage dating back Maratha Empire , Pune evolved bustling metropolis retaining cultural charm . Known pleasant climate throughout year , Pune attracts student , professional , tourist alike . city boast blend modern infrastructure historical landmark , Shaniwar Wada , Aga Khan Palace , Sinhagad Fort . Pune also famous educational institution , including renowned university like Savitribai Phule Pune University Indian Institute Science Education Research ( IISER ) . hub manufacturing industry , Pune contributes significantly India 's economy home numerous multinational corporation . city 's diverse culinary scene offer range delicious street food , Maharashtrian delicacy , international cuisine . Pune 's lively street market upscale mall cater shopping need resident visitor . annual Ganesh Chaturthi festival celebrated great fervor Pune , attracting devotee country . Pune 's nightlife scene vibrant , plethora bar , pub , lounge offering entertainment option taste . city surrounded picturesque hill scenic landscape , making popular destination nature lover adventure enthusiast . Pune 's cultural fabric enriched thriving music , art , theater community , hosting numerous event festival year-round . local transportation network , including bus suburban train , facilitates easy commuting within city nearby town . Pune also known thriving startup ecosystem , fostering innovation entrepreneurship . traditional Maharashtrian hospitality evident Pune 's welcoming atmosphere friendly local . city 's diverse population reflects cosmopolitan character , people various background living harmoniously . Pune 's educational institution attract student India also around world , contributing multicultural environment . Pune 's strategic location , close Mumbai , India 's financial capital , enhances significance major economic cultural center . city 's cultural heritage preserved various initiative , including museum , heritage walk , conservation effort . Overall , Pune 's dynamic blend history , culture , education , industry make city unique charm endless opportunity exploration .
#
# TF-IDF Representation:
#    adventure       aga     alike      also    annual    around       art  \
# 0   0.040757  0.040757  0.040757  0.122271  0.040757  0.040757  0.040757
#
#    atmosphere   attract  attracting  ...   upscale   various   vibrant  \
# 0    0.040757  0.040757    0.040757  ...  0.040757  0.081514  0.081514
#
#     visitor      wada      walk  welcoming    within     world      year
# 0  0.040757  0.040757  0.040757   0.040757  0.040757  0.040757  0.081514
#
# [1 rows x 198 columns]
